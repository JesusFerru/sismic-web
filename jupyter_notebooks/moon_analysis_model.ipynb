# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Ruta de la carpeta que contiene los archivos CSV
folder_path = r'C:\Users\Miguel Angel\Desktop\spaceapp\space_apps_2024_seismic_detection\data\lunar\training\data\S12_GradeA'

# Leer y combinar todos los archivos CSV en un DataFrame
dataframes = []

# Recorrer cada archivo CSV en la carpeta
for file_name in os.listdir(folder_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(folder_path, file_name)
        df = pd.read_csv(file_path)
        dataframes.append(df)

# Combinar todos los DataFrames en uno solo
df = pd.concat(dataframes, ignore_index=True)

# Ordenar los datos por tiempo absoluto
df = df.sort_values('time_abs(%Y-%m-%dT%H:%M:%S.%f)')

# Convertir la columna de tiempo absoluto a formato de fecha y hora
df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'] = pd.to_datetime(df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'])

# Análisis descriptivo de la velocidad
velocity_stats = df['velocity(m/s)'].describe()

print("\nAnálisis descriptivo completo de la velocidad:")
print(velocity_stats)

# Extraer valores mínimos y máximos de la velocidad
velocity_min = df['velocity(m/s)'].min()
velocity_max = df['velocity(m/s)'].max()

print(f"\nVelocidad mínima: {velocity_min}")
print(f"Velocidad máxima: {velocity_max}")

# Parámetros para el cálculo de STA/LTA
sampling_rate = 6  # Número de muestras por segundo (ajústalo según tus datos)
sta_window = 1 * sampling_rate  # Ventana corta de 1 segundo
lta_window = 10 * sampling_rate  # Ventana larga de 10 segundos

# Calcular la media móvil (STA y LTA)
sta = df['velocity(m/s)'].rolling(window=sta_window).mean()
lta = df['velocity(m/s)'].rolling(window=lta_window).mean()

# Evitar división por cero en la LTA reemplazando ceros por NaN
lta = lta.replace(0, np.nan)

# Relación STA/LTA
sta_lta_ratio = sta / lta

# Establecer un umbral para detectar eventos sísmicos
threshold = 3  # Este umbral puede ajustarse según sea necesario
event_detection = sta_lta_ratio > threshold

# Extraer los tiempos donde se detectaron eventos sísmicos
event_times = df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'][event_detection]

# Agrupar los eventos sísmicos por día
event_days = event_times.dt.date.unique()

# Mostrar las fechas en las que se detectaron eventos sísmicos
print("\nDías donde se detectaron eventos sísmicos o anomalías:")
for day in event_days:
    print(f"Se detectaron eventos sísmicos el día: {day}")

# ------------------------------------------------------------
# Graficar la señal de velocidad y la relación STA/LTA en función del tiempo absoluto
# ------------------------------------------------------------
plt.figure(figsize=(12, 6))

# Gráfico de la señal de velocidad
plt.subplot(2, 1, 1)
plt.plot(df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'], df['velocity(m/s)'], label="Señal de velocidad")
plt.title("Señal de velocidad en función del tiempo absoluto")
plt.xlabel("Tiempo absoluto")
plt.ylabel("Velocidad (m/s)")
plt.legend()

# Gráfico de la relación STA/LTA
plt.subplot(2, 1, 2)
plt.plot(df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'], sta_lta_ratio, label="Relación STA/LTA", color='red')
plt.axhline(y=threshold, color='green', linestyle='--', label="Umbral")
plt.title("Relación STA/LTA en función del tiempo absoluto")
plt.xlabel("Tiempo absoluto")
plt.ylabel("Relación STA/LTA")
plt.legend()

plt.tight_layout()
plt.show()

# Extraer columnas de día, mes y año
df['year'] = df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'].dt.year
df['month'] = df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'].dt.month
df['day'] = df['time_abs(%Y-%m-%dT%H:%M:%S.%f)'].dt.day

# Promedio de velocidad por día
daily_avg = df.groupby('day')['velocity(m/s)'].mean()
plt.figure(figsize=(10, 5))
plt.plot(daily_avg.index, daily_avg.values, label='Promedio diario')
plt.title("Promedio diario de la velocidad (m/s)")
plt.xlabel("Día")
plt.ylabel("Velocidad promedio (m/s)")
plt.legend()
plt.show()

# Promedio de velocidad por mes
monthly_avg = df.groupby('month')['velocity(m/s)'].mean()
plt.figure(figsize=(10, 5))
plt.plot(monthly_avg.index, monthly_avg.values, label='Promedio mensual', color='orange')
plt.title("Promedio mensual de la velocidad (m/s)")
plt.xlabel("Mes")
plt.ylabel("Velocidad promedio (m/s)")
plt.legend()
plt.show()

# Promedio de velocidad por año
yearly_avg = df.groupby('year')['velocity(m/s)'].mean()
plt.figure(figsize=(10, 5))
plt.plot(yearly_avg.index, yearly_avg.values, label='Promedio anual', color='green')
plt.title("Promedio anual de la velocidad (m/s)")
plt.xlabel("Año")
plt.ylabel("Velocidad promedio (m/s)")
plt.legend()
plt.show(),
# Out:
# Análisis descriptivo completo de la velocidad:
# count    4.317543e+07
# mean    -7.625022e-13
# std      1.209250e-09
# min     -1.496286e-07
# 25%     -9.761695e-11
# 50%     -1.511219e-18
# 75%      9.754271e-11
# max      1.473143e-07
# Name: velocity(m/s), dtype: float64
#
# Velocidad mínima: -1.4962862873198858e-07
# Velocidad máxima: 1.4731434845499466e-07
#
# Días donde se detectaron eventos sísmicos o anomalías:
# Se detectaron eventos sísmicos el día: 1970-01-19
# Se detectaron eventos sísmicos el día: 1970-01-20
# Se detectaron eventos sísmicos el día: 1970-03-25
# Se detectaron eventos sísmicos el día: 1970-03-26
# Se detectaron eventos sísmicos el día: 1970-03-27
# Se detectaron eventos sísmicos el día: 1970-04-25
# Se detectaron eventos sísmicos el día: 1970-04-26
# Se detectaron eventos sísmicos el día: 1970-06-15
# Se detectaron eventos sísmicos el día: 1970-06-16
# Se detectaron eventos sísmicos el día: 1970-06-26
# Se detectaron eventos sísmicos el día: 1970-06-27
# Se detectaron eventos sísmicos el día: 1970-07-20
# Se detectaron eventos sísmicos el día: 1970-07-21
# Se detectaron eventos sísmicos el día: 1970-09-26
# Se detectaron eventos sísmicos el día: 1970-09-27
# Se detectaron eventos sísmicos el día: 1970-10-24
# Se detectaron eventos sísmicos el día: 1970-10-25
# Se detectaron eventos sísmicos el día: 1970-11-12
# Se detectaron eventos sísmicos el día: 1970-12-11
# Se detectaron eventos sísmicos el día: 1970-12-12
# Se detectaron eventos sísmicos el día: 1970-12-27
# Se detectaron eventos sísmicos el día: 1970-12-28
# Se detectaron eventos sísmicos el día: 1970-12-31
# Se detectaron eventos sísmicos el día: 1971-01-15
# Se detectaron eventos sísmicos el día: 1971-01-16
# Se detectaron eventos sísmicos el día: 1971-01-28
# Se detectaron eventos sísmicos el día: 1971-01-29
# Se detectaron eventos sísmicos el día: 1971-01-30
# Se detectaron eventos sísmicos el día: 1971-02-09
# Se detectaron eventos sísmicos el día: 1971-02-10
# Se detectaron eventos sísmicos el día: 1971-03-25
# Se detectaron eventos sísmicos el día: 1971-03-26
# Se detectaron eventos sísmicos el día: 1971-04-13
# Se detectaron eventos sísmicos el día: 1971-04-17
# Se detectaron eventos sísmicos el día: 1971-04-18
# Se detectaron eventos sísmicos el día: 1971-05-12
# Se detectaron eventos sísmicos el día: 1971-05-13
# Se detectaron eventos sísmicos el día: 1971-05-14
# Se detectaron eventos sísmicos el día: 1971-05-23
# Se detectaron eventos sísmicos el día: 1971-05-24
# Se detectaron eventos sísmicos el día: 1971-06-12
# Se detectaron eventos sísmicos el día: 1971-06-13
# Se detectaron eventos sísmicos el día: 1971-09-25
# Se detectaron eventos sísmicos el día: 1971-10-18
# Se detectaron eventos sísmicos el día: 1971-10-20
# Se detectaron eventos sísmicos el día: 1971-10-31
# Se detectaron eventos sísmicos el día: 1971-11-14
# Se detectaron eventos sísmicos el día: 1972-01-04
# Se detectaron eventos sísmicos el día: 1972-01-05
# Se detectaron eventos sísmicos el día: 1972-03-12
# Se detectaron eventos sísmicos el día: 1972-05-11
# Se detectaron eventos sísmicos el día: 1972-06-16
# Se detectaron eventos sísmicos el día: 1972-07-17
# Se detectaron eventos sísmicos el día: 1972-07-28
# Se detectaron eventos sísmicos el día: 1972-07-29
# Se detectaron eventos sísmicos el día: 1972-07-31
# Se detectaron eventos sísmicos el día: 1972-08-01
# Se detectaron eventos sísmicos el día: 1972-12-02
# Se detectaron eventos sísmicos el día: 1972-12-03
# Se detectaron eventos sísmicos el día: 1973-01-18
# Se detectaron eventos sísmicos el día: 1973-01-19
# Se detectaron eventos sísmicos el día: 1973-01-31
# Se detectaron eventos sísmicos el día: 1973-03-01
# Se detectaron eventos sísmicos el día: 1973-03-13
# Se detectaron eventos sísmicos el día: 1973-03-24
# Se detectaron eventos sísmicos el día: 1973-05-14
# Se detectaron eventos sísmicos el día: 1973-05-15
# Se detectaron eventos sísmicos el día: 1973-06-05
# Se detectaron eventos sísmicos el día: 1973-06-18
# Se detectaron eventos sísmicos el día: 1973-06-19
# Se detectaron eventos sísmicos el día: 1973-06-27
# Se detectaron eventos sísmicos el día: 1973-07-03
# Se detectaron eventos sísmicos el día: 1973-07-04
# Se detectaron eventos sísmicos el día: 1973-07-20
# Se detectaron eventos sísmicos el día: 1973-07-21
# Se detectaron eventos sísmicos el día: 1973-07-28
# Se detectaron eventos sísmicos el día: 1973-07-29
# Se detectaron eventos sísmicos el día: 1973-08-21
# Se detectaron eventos sísmicos el día: 1973-08-22
# Se detectaron eventos sísmicos el día: 1974-01-10
# Se detectaron eventos sísmicos el día: 1974-01-11
# Se detectaron eventos sísmicos el día: 1974-02-07
# Se detectaron eventos sísmicos el día: 1974-02-08
# Se detectaron eventos sísmicos el día: 1974-02-12
# Se detectaron eventos sísmicos el día: 1974-02-13
# Se detectaron eventos sísmicos el día: 1974-03-25
# Se detectaron eventos sísmicos el día: 1974-04-08
# Se detectaron eventos sísmicos el día: 1974-04-09
# Se detectaron eventos sísmicos el día: 1974-04-19
# Se detectaron eventos sísmicos el día: 1974-04-26
# Se detectaron eventos sísmicos el día: 1974-04-27
# Se detectaron eventos sísmicos el día: 1974-06-25
# Se detectaron eventos sísmicos el día: 1974-06-26
# Se detectaron eventos sísmicos el día: 1974-07-06
# Se detectaron eventos sísmicos el día: 1974-07-07
# Se detectaron eventos sísmicos el día: 1974-07-11
# Se detectaron eventos sísmicos el día: 1974-07-12
# Se detectaron eventos sísmicos el día: 1974-07-17
# Se detectaron eventos sísmicos el día: 1974-07-18
# Se detectaron eventos sísmicos el día: 1974-10-14
# Se detectaron eventos sísmicos el día: 1974-10-15
# Se detectaron eventos sísmicos el día: 1975-04-12
# Se detectaron eventos sísmicos el día: 1975-04-13
# Se detectaron eventos sísmicos el día: 1975-05-04
# Se detectaron eventos sísmicos el día: 1975-05-05
# Se detectaron eventos sísmicos el día: 1975-06-24
# Se detectaron eventos sísmicos el día: 1975-06-25
# Se detectaron eventos sísmicos el día: 1975-06-26
# Se detectaron eventos sísmicos el día: 1975-06-27
